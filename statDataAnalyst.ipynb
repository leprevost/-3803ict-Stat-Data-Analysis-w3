# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets,svm, metrics
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

# %%
digits = datasets.load_digits()
x = digits.data
y = digits.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
### Classification

# %%
# 1
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 9)
knn.fit(x_train,y_train)
knn.predict(x_test)[0:15]
knn.score(x_test, y_test)
# Out:
# 0.9916666666666667

# %% [markdown]
# As the number of neighbors increase (in a logarithmic way) there is a clear loss of accuracy

# %%
# 2
model_linear = SVC(kernel='poly')
model_linear.fit(x_train, y_train)

# predict
y_pred = model_linear.predict(x_test)
knn.score(x_test, y_pred)
# Out:
# 0.9861111111111112

# %%
Linear: 97-98%
rbf: 98-99%
poly: 99%

# %%
# 3

# %%
### Regression

# %%
# 1
df = pd.read_csv('../gapminder.csv')  
df.head()
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), annot = True, cmap='inferno')
data = df
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male    GDP  BMI_female  life  \
# 0    34811059       2.73  0.1   3.328945  24.59620  12314    129.9049  75.3
# 1    19842251       6.43  2.0   1.474353  22.25083   7103    130.1247  58.3
# 2    40381860       2.24  0.5   4.785170  27.50170  14646    118.8915  75.5
# 3     2975029       1.40  0.1   1.804106  25.35542   7383    132.8108  72.5
# 4    21370348       1.96  0.1  18.016313  27.56373  41312    117.3755  81.5
#
#    child_mortality                      Region
# 0             29.5  Middle East & North Africa
# 1            192.0          Sub-Saharan Africa
# 2             15.4                     America
# 3             20.0       Europe & Central Asia
# 4              5.2         East Asia & Pacific

# %%
from sklearn.linear_model import LinearRegression 
X = df['fertility'].values.reshape(-1, 1)
Y = df['life'].values.reshape(-1, 1) 

linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.xlabel('fertility')
plt.ylabel('life expectancy')
plt.show()

# %%
Y = df['HIV'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('HIV')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['CO2'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('CO2')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['population'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('population')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['BMI_male'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('BMI_male')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['BMI_female'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('BMI_female')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['GDP'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('GDP')
plt.xlabel('life expectancy')
plt.show()

# %%
Y = df['child_mortality'].values.reshape(-1, 1)
X = df['life'].values.reshape(-1, 1) 
linear_regressor = LinearRegression()  
linear_regressor.fit(X, Y)  
Y_pred = linear_regressor.predict(X)  

plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.ylabel('Child_mortality')
plt.xlabel('life expectancy')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(clf, X, Y, cv=5)
scores()
# Out:
# /home/matcha/.local/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/matcha/.local/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# /home/matcha/.local/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Logistic Regression
dg = pd.read_csv('../creditcard.csv')  
#dg.head()
frauds = dg.loc[df['Class'] == 1]
non_frauds = dg.loc[df['Class'] == 0]
print(len(frauds), "frauds, ", len(non_frauds), "nnonfrauds, ")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-95143781526a> in <module>
#       2 dg = pd.read_csv('../creditcard.csv')
# ...
